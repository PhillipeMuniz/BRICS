# %% [markdown]
# # India

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
total = pd.read_excel("total.xlsx")

# %%
total.head(5)
# Out:
#   Country Name Country Code    Time Time Code  \
# 0       Brazil          BRA  1960.0    YR1960
# 1       Brazil          BRA  1961.0    YR1961
# 2       Brazil          BRA  1962.0    YR1962
# 3       Brazil          BRA  1963.0    YR1963
# 4       Brazil          BRA  1964.0    YR1964
#
#   Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]  \
# 0                                              43.86
# 1                                             43.431
# 2                                             42.844
# 3                                             42.176
# 4                                             41.238
#
#   GDP growth (annual %) [NY.GDP.MKTP.KD.ZG]  \
# 0                                        ..
# 1                                       8.6
# 2                                       6.6
# 3                                       0.6
# 4                                       3.4
#
#   GDP per capita (current US$) [NY.GDP.PCAP.CD]  \
# 0                                    232.998762
# 1                                    229.336766
# 2                                      247.8343
# 3                                    291.404006
# 4                                    254.838581
#
#   GDP per capita growth (annual %) [NY.GDP.PCAP.KD.ZG]  \
# 0                                                 ..
# 1                                           5.374304
# 2                                           3.482729
# 3                                          -2.315872
# 4                                           0.449644
#
#   GDP (current US$) [NY.GDP.MKTP.CD]  \
# 0                 17030465539.390615
# 1                 17275940449.383743
# 2                 19231747851.533188
# 3                  23287712878.20023
# 4                 20963733694.974895
#
#   Death rate, crude (per 1,000 people) [SP.DYN.CDRT.IN]  ...  \
# 0                                             14.025     ...
# 1                                             13.662     ...
# 2                                             13.301     ...
# 3                                             12.952     ...
# 4                                             12.621     ...
#
#   Urban population (% of total population) [SP.URB.TOTL.IN.ZS]  \
# 0                                             46.139
# 1                                             47.122
# 2                                             48.099
# 3                                             49.078
# 4                                             50.059
#
#   Urban population [SP.URB.TOTL]  \
# 0                       33724155
# 1                       35497006
# 2                       37324448
# 3                       39220956
# 4                       41179932
#
#   Rural population growth (annual %) [SP.RUR.TOTL.ZG]  \
# 0                                                 ..
# 1                                           1.173332
# 2                                           1.102945
# 3                                           1.037016
# 4                                           0.949567
#
#   Rural population (% of total population) [SP.RUR.TOTL.ZS]  \
# 0                                             53.861
# 1                                             52.878
# 2                                             51.901
# 3                                             50.922
# 4                                             49.941
#
#   Rural population [SP.RUR.TOTL]  \
# 0                       39368360
# 1                       39833002
# 2                       40274770
# 3                       40694599
# 4                       41082862
#
#   Research and development expenditure (% of GDP) [GB.XPD.RSDV.GD.ZS]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Domestic general government health expenditure (% of general government expenditure) [SH.XPD.GHED.GE.ZS]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Military expenditure (% of GDP) [MS.MIL.XPND.GD.ZS]  \
# 0                                           2.679135
# 1                                           2.364066
# 2                                           2.398683
# 3                                           2.260839
# 4                                           2.014498
#
#   Population density (people per sq. km of land area) [EN.POP.DNST]  \
# 0                                                 ..
# 1                                           9.012772
# 2                                           9.284269
# 3                                           9.561404
# 4                                           9.842237
#
#   Population, total [SP.POP.TOTL]
# 0                        73092515
# 1                        75330008
# 2                        77599218
# 3                        79915555
# 4                        82262794
#
# [5 rows x 23 columns]

# %%
ind_filter = total['Country Name'] == 'India'
ind = total[ind_filter]

# %%
ind.columns
# Out:
# Index(['Country Name', 'Country Code', 'Time', 'Time Code',
#        'Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]',
#        'GDP growth (annual %) [NY.GDP.MKTP.KD.ZG]',
#        'GDP per capita (current US$) [NY.GDP.PCAP.CD]',
#        'GDP per capita growth (annual %) [NY.GDP.PCAP.KD.ZG]',
#        'GDP (current US$) [NY.GDP.MKTP.CD]',
#        'Death rate, crude (per 1,000 people) [SP.DYN.CDRT.IN]',
#        'Government expenditure on education, total (% of GDP) [SE.XPD.TOTL.GD.ZS]',
#        'Life expectancy at birth, total (years) [SP.DYN.LE00.IN]',
#        'Urban population growth (annual %) [SP.URB.GROW]',
#        'Urban population (% of total population) [SP.URB.TOTL.IN.ZS]',
#        'Urban population [SP.URB.TOTL]',
#        'Rural population growth (annual %) [SP.RUR.TOTL.ZG]',
#        'Rural population (% of total population) [SP.RUR.TOTL.ZS]',
#        'Rural population [SP.RUR.TOTL]',
#        'Research and development expenditure (% of GDP) [GB.XPD.RSDV.GD.ZS]',
#        'Domestic general government health expenditure (% of general government expenditure) [SH.XPD.GHED.GE.ZS]',
#        'Military expenditure (% of GDP) [MS.MIL.XPND.GD.ZS]',
#        'Population density (people per sq. km of land area) [EN.POP.DNST]',
#        'Population, total [SP.POP.TOTL]'],
#       dtype='object')

# %% [markdown]
# Criando uma função para obter os informação do dataframe

# %%
def df_informacoes(df):
    df_info = pd.DataFrame({'Não Nulos': df.notnull().sum(),
                'Nulos': df.isnull().sum(),
                '% Nulos': ((df.isnull().sum()/df.notnull().sum())*100).round(2),                         
                'Unicos': df.nunique(),                  
                'Dtype': df.dtypes})
    df_info.index.name = 'Columns'
    return df_info

# %%
df_informacoes(ind)
# Out:
#                                                     Não Nulos  Nulos  % Nulos  \
# Columns
# Country Name                                               63      0      0.0
# Country Code                                               63      0      0.0
# Time                                                       63      0      0.0
# Time Code                                                  63      0      0.0
# Birth rate, crude (per 1,000 people) [SP.DYN.CB...         63      0      0.0
# GDP growth (annual %) [NY.GDP.MKTP.KD.ZG]                  63      0      0.0
# GDP per capita (current US$) [NY.GDP.PCAP.CD]              63      0      0.0
# GDP per capita growth (annual %) [NY.GDP.PCAP.K...         63      0      0.0
# GDP (current US$) [NY.GDP.MKTP.CD]                         63      0      0.0
# Death rate, crude (per 1,000 people) [SP.DYN.CD...         63      0      0.0
# Government expenditure on education, total (% o...         63      0      0.0
# Life expectancy at birth, total (years) [SP.DYN...         63      0      0.0
# Urban population growth (annual %) [SP.URB.GROW]           63      0      0.0
# Urban population (% of total population) [SP.UR...         63      0      0.0
# Urban population [SP.URB.TOTL]                             63      0      0.0
# Rural population growth (annual %) [SP.RUR.TOTL...         63      0      0.0
# Rural population (% of total population) [SP.RU...         63      0      0.0
# Rural population [SP.RUR.TOTL]                             63      0      0.0
# Research and development expenditure (% of GDP)...         63      0      0.0
# Domestic general government health expenditure ...         63      0      0.0
# Military expenditure (% of GDP) [MS.MIL.XPND.GD...         63      0      0.0
# Population density (people per sq. km of land a...         63      0      0.0
# Population, total [SP.POP.TOTL]                            63      0      0.0
#
#                                                     Unicos    Dtype
# Columns
# Country Name                                             1   object
# Country Code                                             1   object
# Time                                                    63  float64
# Time Code                                               63   object
# Birth rate, crude (per 1,000 people) [SP.DYN.CB...      63   object
# GDP growth (annual %) [NY.GDP.MKTP.KD.ZG]               62   object
# GDP per capita (current US$) [NY.GDP.PCAP.CD]           63   object
# GDP per capita growth (annual %) [NY.GDP.PCAP.K...      62   object
# GDP (current US$) [NY.GDP.MKTP.CD]                      63   object
# Death rate, crude (per 1,000 people) [SP.DYN.CD...      63   object
# Government expenditure on education, total (% o...      20   object
# Life expectancy at birth, total (years) [SP.DYN...      63   object
# Urban population growth (annual %) [SP.URB.GROW]        62   object
# Urban population (% of total population) [SP.UR...      63   object
# Urban population [SP.URB.TOTL]                          63   object
# Rural population growth (annual %) [SP.RUR.TOTL...      62   object
# Rural population (% of total population) [SP.RU...      63   object
# Rural population [SP.RUR.TOTL]                          63   object
# Research and development expenditure (% of GDP)...      17   object
# Domestic general government health expenditure ...      22   object
# Military expenditure (% of GDP) [MS.MIL.XPND.GD...      63   object
# Population density (people per sq. km of land a...      61   object
# Population, total [SP.POP.TOTL]                         63   object

# %%
ind.columns
# Out:
# Index(['Country Name', 'Country Code', 'Time', 'Time Code',
#        'Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]',
#        'GDP growth (annual %) [NY.GDP.MKTP.KD.ZG]',
#        'GDP per capita (current US$) [NY.GDP.PCAP.CD]',
#        'GDP per capita growth (annual %) [NY.GDP.PCAP.KD.ZG]',
#        'GDP (current US$) [NY.GDP.MKTP.CD]',
#        'Death rate, crude (per 1,000 people) [SP.DYN.CDRT.IN]',
#        'Government expenditure on education, total (% of GDP) [SE.XPD.TOTL.GD.ZS]',
#        'Life expectancy at birth, total (years) [SP.DYN.LE00.IN]',
#        'Urban population growth (annual %) [SP.URB.GROW]',
#        'Urban population (% of total population) [SP.URB.TOTL.IN.ZS]',
#        'Urban population [SP.URB.TOTL]',
#        'Rural population growth (annual %) [SP.RUR.TOTL.ZG]',
#        'Rural population (% of total population) [SP.RUR.TOTL.ZS]',
#        'Rural population [SP.RUR.TOTL]',
#        'Research and development expenditure (% of GDP) [GB.XPD.RSDV.GD.ZS]',
#        'Domestic general government health expenditure (% of general government expenditure) [SH.XPD.GHED.GE.ZS]',
#        'Military expenditure (% of GDP) [MS.MIL.XPND.GD.ZS]',
#        'Population density (people per sq. km of land area) [EN.POP.DNST]',
#        'Population, total [SP.POP.TOTL]'],
#       dtype='object')

# %% [markdown]
# Renomeando variáveis

# %%
ind.rename(columns={'Country Name': 'Nome_do_pais',
                     'Country Code': 'Codigo_do_pais',
                     'Time': 'Ano',
                     'Time Code': 'Codigo_do_tempo',
                     'Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]': 'Taxa_de_natalidade',
                     'GDP (current US$) [NY.GDP.MKTP.CD]': 'Pib',
                     'GDP growth (annual %) [NY.GDP.MKTP.KD.ZG]': 'Crescimento_do_pib',
                     'GDP per capita growth (annual %) [NY.GDP.PCAP.KD.ZG]': 'Crescimento_do_pib_per_capita',
                     'GDP per capita (current US$) [NY.GDP.PCAP.CD]': 'Pib_per_capita',
                     'Death rate, crude (per 1,000 people) [SP.DYN.CDRT.IN]': 'Taxa_de_mortalidade',
                     'Government expenditure on education, total (% of GDP) [SE.XPD.TOTL.GD.ZS]': 'Despesa_governamental_em_educacao',
                     'Life expectancy at birth, total (years) [SP.DYN.LE00.IN]': 'Expectativa_de_vida_ao_nascer',
                     'Population growth (annual %) [SP.POP.GROW]': 'Crescimento_populacional',
                     'Research and development expenditure (% of GDP) [GB.XPD.RSDV.GD.ZS]': 'Despesa_em_pesquisa_e_desenvolvimento',
                     'Rural population (% of total population) [SP.RUR.TOTL.ZS]': 'Populacao_rural_percentual',
                     'Rural population [SP.RUR.TOTL]': 'Populacao_rural_total',
                     'Urban population [SP.URB.TOTL]': 'Populacao_urbana_total',
                     'Urban population (% of total population) [SP.URB.TOTL.IN.ZS]': 'Populacao_urbana_percentual',
                     'Military expenditure (% of GDP) [MS.MIL.XPND.GD.ZS]': 'Despesa_militar_percentual',
                     'Domestic general government health expenditure (% of general government expenditure) [SH.XPD.GHED.GE.ZS]': 'Gasto_governamental_saude',
                     'Population density (people per sq. km of land area) [EN.POP.DNST]': 'Densidade_populacional',
                     'Population, total [SP.POP.TOTL]': 'Populacao_total',
                     'Urban population growth (annual %) [SP.URB.GROW]': 'Crescimento_populacao_urbana',
                     'Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]': 'Taxa_de_natalidade',
                     'Rural population growth (annual %) [SP.RUR.TOTL.ZG]': 'Crescimento_populacao_rural'}, inplace=True)
# Out:
# c:\Users\phill\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(ind['Despesa_em_pesquisa_e_desenvolvimento'].unique())
# Out:
# ['..' 0.628040015697479 0.674849987030029 0.691659986972809
#  0.711650013923645 0.743950009346008 0.723230004310608 0.71315997838974
#  0.706889986991882 0.743849992752075 0.810440003871918 0.79721999168396
#  0.790799975395203 0.841080009937286 0.818809986114502 0.797179996967316
#  0.822239995002747]

# %%
def convert_to_float(bra, columns):
    for col in columns:
        bra[col] = pd.to_numeric(bra[col], errors='coerce')
    return bra

# lista de colunas a serem convertidas para float
columns = ['Taxa_de_natalidade', 'Crescimento_do_pib', 'Pib_per_capita',
       'Crescimento_do_pib_per_capita', 'Pib', 'Taxa_de_mortalidade',
       'Despesa_governamental_em_educacao', 'Expectativa_de_vida_ao_nascer',
       'Crescimento_populacao_urbana', 'Populacao_urbana_percentual',
       'Populacao_urbana_total', 'Crescimento_populacao_rural',
       'Populacao_rural_percentual', 'Populacao_rural_total',
       'Despesa_em_pesquisa_e_desenvolvimento', 'Gasto_governamental_saude',
       'Despesa_militar_percentual', 'Densidade_populacional',
       'Populacao_total']

# chama a função convert_to_float passando o DataFrame e a lista de colunas como argumentos
df = convert_to_float(ind, columns)

# exibe as informações do DataFrame após a conversão de tipo
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63 entries, 189 to 251
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Nome_do_pais                           63 non-null     object
#  1   Codigo_do_pais                         63 non-null     object
#  2   Ano                                    63 non-null     float64
#  3   Codigo_do_tempo                        63 non-null     object
#  4   Taxa_de_natalidade                     62 non-null     float64
#  5   Crescimento_do_pib                     61 non-null     float64
#  6   Pib_per_capita                         62 non-null     float64
#  7   Crescimento_do_pib_per_capita          61 non-null     float64
#  8   Pib                                    62 non-null     float64
#  9   Taxa_de_mortalidade                    62 non-null     float64
#  10  Despesa_governamental_em_educacao      19 non-null     float64
#  11  Expectativa_de_vida_ao_nascer          62 non-null     float64
#  12  Crescimento_populacao_urbana           61 non-null     float64
#  13  Populacao_urbana_percentual            62 non-null     float64
#  14  Populacao_urbana_total                 62 non-null     float64
#  15  Crescimento_populacao_rural            61 non-null     float64
#  16  Populacao_rural_percentual             62 non-null     float64
#  17  Populacao_rural_total                  62 non-null     float64
#  18  Despesa_em_pesquisa_e_desenvolvimento  16 non-null     float64
#  19  Gasto_governamental_saude              21 non-null     float64
#  20  Despesa_militar_percentual             62 non-null     float64
#  21  Densidade_populacional                 60 non-null     float64
#  22  Populacao_total                        62 non-null     float64
# dtypes: float64(20), object(3)
# memory usage: 11.8+ KB
# None
# <ipython-input-65-e1cd4d0adb53>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ind.tail(20)
# Out:
#     Nome_do_pais Codigo_do_pais     Ano Codigo_do_tempo  Taxa_de_natalidade  \
# 232        India            IND  2003.0          YR2003              25.375
# 233        India            IND  2004.0          YR2004              24.728
# 234        India            IND  2005.0          YR2005              23.940
# 235        India            IND  2006.0          YR2006              23.220
# 236        India            IND  2007.0          YR2007              22.713
# 237        India            IND  2008.0          YR2008              22.276
# 238        India            IND  2009.0          YR2009              21.934
# 239        India            IND  2010.0          YR2010              21.438
# 240        India            IND  2011.0          YR2011              20.945
# 241        India            IND  2012.0          YR2012              20.421
# 242        India            IND  2013.0          YR2013              19.935
# 243        India            IND  2014.0          YR2014              19.049
# 244        India            IND  2015.0          YR2015              18.765
# 245        India            IND  2016.0          YR2016              18.514
# 246        India            IND  2017.0          YR2017              17.911
# 247        India            IND  2018.0          YR2018              17.651
# 248        India            IND  2019.0          YR2019              17.049
# 249        India            IND  2020.0          YR2020              16.572
# 250        India            IND  2021.0          YR2021              16.419
# 251        India            IND  2022.0          YR2022                 NaN
#
#      Crescimento_do_pib  Pib_per_capita  Crescimento_do_pib_per_capita  \
# 232            7.860381      543.843799                       6.016521
# 233            7.922937      624.105094                       6.132606
# 234            7.923431      710.509345                       6.206011
# 235            8.060733      802.013742                       6.426045
# 236            7.660815     1022.731629                       6.093626
# 237            3.086698      993.503772                       1.630781
# 238            7.861889     1096.634980                       6.371709
# 239            8.497585     1350.634322                       7.013175
# 240            5.241315     1449.601789                       3.818073
# 241            5.456389     1434.018198                       4.060824
# 242            6.386106     1438.057480                       5.014612
# 243            7.410228     1559.864518                       6.086180
# 244            7.996254     1590.173918                       6.721068
# 245            8.256306     1714.280355                       6.980990
# 246            6.795383     1957.968841                       5.568334
# 247            6.453851     1974.377788                       5.302409
# 248            3.737919     2047.232704                       2.679717
# 249           -6.596081     1910.421473                      -7.484046
# 250            8.681229     2256.590409                       7.818249
# 251                 NaN             NaN                            NaN
#
#               Pib  Taxa_de_mortalidade  ...  Populacao_urbana_percentual  \
# 232  6.076993e+11                8.188  ...                       28.572
# 233  7.091485e+11                8.040  ...                       28.903
# 234  8.203816e+11                7.876  ...                       29.235
# 235  9.402599e+11                7.743  ...                       29.569
# 236  1.216735e+12                7.642  ...                       29.906
# 237  1.198896e+12                7.558  ...                       30.246
# 238  1.341887e+12                7.479  ...                       30.587
# 239  1.675615e+12                7.385  ...                       30.930
# 240  1.823050e+12                7.267  ...                       31.276
# 241  1.827638e+12                7.118  ...                       31.634
# 242  1.856722e+12                6.960  ...                       32.003
# 243  2.039127e+12                6.790  ...                       32.384
# 244  2.103588e+12                6.670  ...                       32.777
# 245  2.294798e+12                6.603  ...                       33.182
# 246  2.651473e+12                6.593  ...                       33.600
# 247  2.702930e+12                6.644  ...                       34.030
# 248  2.831552e+12                6.710  ...                       34.472
# 249  2.667688e+12                7.350  ...                       34.926
# 250  3.176295e+12                9.448  ...                       35.393
# 251           NaN                  NaN  ...                          NaN
#
#      Populacao_urbana_total  Crescimento_populacao_rural  \
# 232             319267849.0                     1.266117
# 233             328414552.0                     1.208330
# 234             337558628.0                     1.136068
# 235             346659205.0                     1.051206
# 236             355789232.0                     0.986741
# 237             364989009.0                     0.936148
# 238             374274816.0                     0.901135
# 239             383721793.0                     0.882227
# 240             393333604.0                     0.859388
# 241             403171286.0                     0.809906
# 242             413200994.0                     0.756345
# 243             423338709.0                     0.678468
# 244             433595954.0                     0.604876
# 245             444186310.0                     0.580752
# 246             455009748.0                     0.528080
# 247             465871825.0                     0.437831
# 248             476786386.0                     0.353055
# 249             487702168.0                     0.259976
# 250             498179071.0                     0.076984
# 251                     NaN                          NaN
#
#      Populacao_rural_percentual  Populacao_rural_total  \
# 232                      71.428            798147274.0
# 233                      71.097            807850031.0
# 234                      70.765            817080085.0
# 235                      70.431            825714583.0
# 236                      70.094            833902577.0
# 237                      69.754            841745797.0
# 238                      69.413            849365344.0
# 239                      69.070            856891827.0
# 240                      68.724            864287587.0
# 241                      68.366            871315929.0
# 242                      67.997            877931069.0
# 243                      67.616            883907800.0
# 244                      67.223            889270551.0
# 245                      66.818            894450030.0
# 246                      66.400            899185932.0
# 247                      65.970            903131481.0
# 248                      65.528            906325664.0
# 249                      65.074            908684959.0
# 250                      64.607            909384771.0
# 251                         NaN                    NaN
#
#      Despesa_em_pesquisa_e_desenvolvimento  Gasto_governamental_saude  \
# 232                                0.70689                   2.745441
# 233                                0.74385                   2.810076
# 234                                0.81044                   3.032887
# 235                                0.79722                   2.952410
# 236                                0.79080                   2.958415
# 237                                0.84108                   2.970895
# 238                                0.81881                   3.193920
# 239                                0.79718                   3.111630
# 240                                0.82224                   3.381301
# 241                                    NaN                   3.438494
# 242                                    NaN                   3.238832
# 243                                    NaN                   3.250705
# 244                                    NaN                   3.376240
# 245                                    NaN                   3.393335
# 246                                    NaN                   3.403053
# 247                                    NaN                   3.455651
# 248                                    NaN                   3.366622
# 249                                    NaN                   3.318891
# 250                                    NaN                        NaN
# 251                                    NaN                        NaN
#
#      Despesa_militar_percentual  Densidade_populacional  Populacao_total
# 232                    2.677777              375.830378     1.117415e+09
# 233                    2.828752              382.170189     1.136265e+09
# 234                    2.754908              388.350127     1.154639e+09
# 235                    2.526809              394.315126     1.172374e+09
# 236                    2.478248              400.139853     1.189692e+09
# 237                    2.631462              405.872079     1.206735e+09
# 238                    3.129387              411.558010     1.223640e+09
# 239                    2.889461              417.266848     1.240614e+09
# 240                    2.704484              422.987159     1.257621e+09
# 241                    2.618168              428.659862     1.274487e+09
# 242                    2.548826              434.258175     1.291132e+09
# 243                    2.543983              439.678093     1.307247e+09
# 244                    2.457451              444.931708     1.322867e+09
# 245                    2.543151              450.235720     1.338636e+09
# 246                    2.531463              455.468934     1.354196e+09
# 247                    2.433922              460.449317     1.369003e+09
# 248                    2.519121              465.194639     1.383112e+09
# 249                    2.884633              469.659567     1.396387e+09
# 250                    2.657790                     NaN     1.407564e+09
# 251                         NaN                     NaN              NaN
#
# [20 rows x 23 columns]

# %%
# cria uma matriz de correlação com apenas os valores da metade superior
corr_matrix = ind.corr().where(np.tril(np.ones(ind.corr().shape), k=1).astype(bool))

# cria um heatmap com a matriz de correlação da metade superior
heatmap = px.imshow(corr_matrix)

# define a largura das células
heatmap.update_layout(width=1000)

# remove os nomes das variáveis nos eixos x e y
heatmap.update_xaxes(title='', showticklabels=False)
heatmap.update_yaxes(title='', showticklabels=False)

# mostra o gráfico
heatmap.show()

# %%
# Calcula a matriz de correlação
corr_matrix = ind.corrwith(ind['Populacao_urbana_total'])

# Cria um DataFrame com as correlações
corr_df = pd.DataFrame({'Correlação': corr_matrix})

# Ordena as correlações em ordem decrescente
corr_df = corr_df.sort_values(by='Correlação', ascending=False)

# Mostra o DataFrame com as correlações
print(corr_df)
# Out:
#                                        Correlação
# Populacao_urbana_total                   1.000000
# Densidade_populacional                   0.993872
# Populacao_total                          0.993224
# Populacao_urbana_percentual              0.992806
# Ano                                      0.987346
# Populacao_rural_total                    0.980379
# Expectativa_de_vida_ao_nascer            0.974652
# Pib_per_capita                           0.928848
# Pib                                      0.915004
# Despesa_em_pesquisa_e_desenvolvimento    0.910191
# Gasto_governamental_saude                0.716397
# Despesa_governamental_em_educacao        0.525753
# Crescimento_do_pib_per_capita            0.366908
# Crescimento_do_pib                       0.247288
# Despesa_militar_percentual              -0.556206
# Crescimento_populacao_urbana            -0.856814
# Taxa_de_mortalidade                     -0.918104
# Crescimento_populacao_rural             -0.951560
# Populacao_rural_percentual              -0.992806
# Taxa_de_natalidade                      -0.996623

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Dados
populacao_urbana = ind['Populacao_urbana_total']
populacao_rural = ind['Populacao_rural_total']
populacao_total = ind['Populacao_total']
anos = ind['Ano']

# Configurações do gráfico
plt.plot(anos, populacao_urbana, label='População Urbana')
plt.plot(anos, populacao_rural, label='População Rural')
plt.plot(anos, populacao_total, label='População Total')
plt.title('Distribuição da População Total, Urbana e Rural (1960-2022)')
plt.xlabel('Ano')

# Define o formato dos tick labels no eixo y
formatter = ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1e6))
plt.gca().yaxis.set_major_formatter(formatter)
plt.ylabel('População (em milhões)')

plt.legend()

# Exibe o gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker



variables = ['Taxa_de_natalidade', 'Crescimento_do_pib', 'Pib_per_capita',
       'Crescimento_do_pib_per_capita', 'Pib', 'Taxa_de_mortalidade',
       'Despesa_governamental_em_educacao', 'Expectativa_de_vida_ao_nascer',
       'Crescimento_populacao_urbana', 'Populacao_urbana_percentual',
       'Populacao_urbana_total', 'Crescimento_populacao_rural',
       'Populacao_rural_percentual', 'Populacao_rural_total',
       'Despesa_em_pesquisa_e_desenvolvimento', 'Gasto_governamental_saude',
       'Despesa_militar_percentual', 'Densidade_populacional',
       'Populacao_total']


# Cria uma matriz de subplots (2 linhas, 5 colunas)
fig, axs = plt.subplots(nrows=5, ncols=4, figsize=(20, 12))

# Cria um índice para iterar sobre as variáveis
var_index = 0

# Itera sobre as linhas e colunas dos subplots
for i in range(5):
    for j in range(4):
        # Se todas as variáveis tiverem sido plotadas, sai do loop
        if var_index == len(variables):
            break
        
        # Plota a variável atual em um subplot específico
        axs[i,j].plot(ind['Ano'], ind[variables[var_index]])
        axs[i,j].set_title(variables[var_index])
        axs[i,j].set_xlabel('Ano')
        axs[i,j].set_ylabel(variables[var_index])

        # Define o formato dos tick labels no eixo y
        if "Populacao" in variables[var_index]:
            # Para variáveis de população, formata em milhões
            formatter = ticker.FuncFormatter(lambda x, pos: '{:.1f} Mi'.format(x/1e6))
            axs[i,j].yaxis.set_major_formatter(formatter)
        elif "Pib" in variables[var_index] and variables[var_index] != 'Pib_per_capita':
            # Para variáveis de PIB, formata em trilhões
            formatter = ticker.FuncFormatter(lambda x, pos: '{:.2f} Tri'.format(x/1e12))
            axs[i,j].yaxis.set_major_formatter(formatter)
        elif "Pib_per_capita" in variables[var_index]:
            # Para variáveis de PIB per capita
            formatter = ticker.FuncFormatter(lambda x, pos: '{:.0f}'.format(x))
            axs[i,j].yaxis.set_major_formatter(formatter)    
        else:
            # Para outras variáveis, usa a notação padrão
            formatter = ticker.ScalarFormatter()
            formatter.set_powerlimits((-3,3))
            axs[i,j].yaxis.set_major_formatter(formatter)
        
        # Incrementa o índice da variável
        var_index += 1
# Ajusta os subplots e o espaçamento
plt.tight_layout()

# Mostra o gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Cria uma figura para o gráfico
fig, ax = plt.subplots(figsize=(10, 7))

# Define o título do gráfico
ax.set_title('Variação da taxa de natalidade e mortalidade em relação ao crescimento populacional (1960-2022)')

# Plota as colunas desejadas em um mesmo gráfico de linha
ax.plot(ind['Ano'], ind['Taxa_de_natalidade'], label='Taxa de Natalidade')
ax.plot(ind['Ano'], ind['Taxa_de_mortalidade'], label='Taxa de Mortalidade')

# Cria um segundo eixo y
ax2 = ax.twinx()

# Plota a coluna de População Total no segundo eixo y em escala de milhões
ax2.plot(ind['Ano'], ind['Populacao_total'] / 1000000, label='População Total', color='y')

# Adiciona legenda aos dois eixos
ax.legend()
ax2.legend(loc='upper center')

# Define o rótulo dos eixos x e y
ax.set_xlabel('Ano')
ax.set_ylabel('Taxa de natalidade e mortalidade (a cada 1000 pessoas)')
ax2.set_ylabel('População (milhões)')

# Move a legenda para fora do gráfico no lado direito
ax.legend(loc='center left', bbox_to_anchor=(1.2, 0.5))
ax2.legend(loc='upper center', bbox_to_anchor=(1.31, 0.62))




# Exibe o gráfico
plt.show()

# %%
# Selecionar apenas as colunas desejadas
ind_despesas = ind[['Nome_do_pais', 'Ano', 'Despesa_em_pesquisa_e_desenvolvimento', 'Gasto_governamental_saude', 'Despesa_governamental_em_educacao']]

# Selecionar apenas os anos maiores ou iguais a 1995
ind_despesas = ind_despesas[ind_despesas['Ano'] >= 1995]

# Fazer a interpolação linear nos valores faltantes
ind_despesas_interpolated = ind_despesas.interpolate()

# Adicionar asteriscos aos novos valores criados pela interpolação
for col in ind_despesas.columns:
    if ind_despesas[col].dtype != 'object': # verificar se a coluna é numérica
        new_values_mask = (ind_despesas_interpolated[col] != ind_despesas[col])
        ind_despesas.loc[new_values_mask, col] = ind_despesas_interpolated[col].round(4).astype(str) + '*'

# Remover asteriscos dos valores nulos
ind_despesas = ind_despesas.replace('nan*', np.nan)

# Exibir a nova tabela
ind_despesas.head(31)

# Exportar a nova tabela em um arquivo CSV
ind_despesas.to_csv('despesas_ind_interp.csv', index=False)

# %%
# Selecionar apenas as colunas desejadas
ind_despesas1 = ind[['Nome_do_pais', 'Ano', 'Despesa_em_pesquisa_e_desenvolvimento', 'Gasto_governamental_saude', 'Despesa_governamental_em_educacao']]

# Selecionar apenas os anos maiores ou iguais a 1995
ind_despesas1 = ind_despesas1[ind_despesas1['Ano'] >= 1995]

# Fazer a interpolação linear nos valores faltantes
ind_despesas_interpolated1 = ind_despesas1.interpolate()

# Converter colunas numércias para float
cols_numeric = ['Despesa_em_pesquisa_e_desenvolvimento', 'Gasto_governamental_saude', 'Despesa_governamental_em_educacao']
ind_despesas_interpolated1[cols_numeric] = ind_despesas_interpolated1[cols_numeric].astype(float)

# Exibir a nova tabela
ind_despesas_interpolated1.head(31)
# Out:
#     Nome_do_pais     Ano  Despesa_em_pesquisa_e_desenvolvimento  \
# 224        India  1995.0                                    NaN
# 225        India  1996.0                                0.62804
# 226        India  1997.0                                0.67485
# 227        India  1998.0                                0.69166
# 228        India  1999.0                                0.71165
# 229        India  2000.0                                0.74395
# 230        India  2001.0                                0.72323
# 231        India  2002.0                                0.71316
# 232        India  2003.0                                0.70689
# 233        India  2004.0                                0.74385
# 234        India  2005.0                                0.81044
# 235        India  2006.0                                0.79722
# 236        India  2007.0                                0.79080
# 237        India  2008.0                                0.84108
# 238        India  2009.0                                0.81881
# 239        India  2010.0                                0.79718
# 240        India  2011.0                                0.82224
# 241        India  2012.0                                0.82224
# 242        India  2013.0                                0.82224
# 243        India  2014.0                                0.82224
# 244        India  2015.0                                0.82224
# 245        India  2016.0                                0.82224
# 246        India  2017.0                                0.82224
# 247        India  2018.0                                0.82224
# 248        India  2019.0                                0.82224
# 249        India  2020.0                                0.82224
# 250        India  2021.0                                0.82224
# 251        India  2022.0                                0.82224
#
#      Gasto_governamental_saude  Despesa_governamental_em_educacao
# 224                        NaN                                NaN
# 225                        NaN                                NaN
# 226                        NaN                           3.361360
# 227                        NaN                           3.572560
# 228                        NaN                           4.415390
# 229                   3.290743                           4.324790
# 230                   3.175101                           4.087663
# 231                   2.868575                           3.850537
# 232                   2.745441                           3.613410
# 233                   2.810076                           3.352540
# 234                   3.032887                           3.188750
# 235                   2.952410                           3.142850
# 236                   2.958415                           3.187983
# 237                   2.970895                           3.233117
# 238                   3.193920                           3.278250
# 239                   3.111630                           3.377690
# 240                   3.381301                           3.796180
# 241                   3.438494                           3.867500
# 242                   3.238832                           3.844670
# 243                   3.250705                           3.979620
# 244                   3.376240                           4.114570
# 245                   3.393335                           4.254080
# 246                   3.403053                           4.305450
# 247                   3.455651                           4.363740
# 248                   3.366622                           4.407230
# 249                   3.318891                           4.474230
# 250                   3.318891                           4.474230
# 251                   3.318891                           4.474230

# %%
# Criar dicionário com novos nomes das colunas
new_cols = {'Despesa_em_pesquisa_e_desenvolvimento': 'P&D', 
            'Gasto_governamental_saude': 'Saúde', 
            'Despesa_governamental_em_educacao': 'Educação'}

# Renomear as colunas
ind_despesas_interpolated1 = ind_despesas_interpolated1.rename(columns=new_cols)

# Selecionar colunas renomeadas para o gráfico
cols = list(new_cols.values())

# Plotar gráfico de linhas
ind_despesas_interpolated1.plot(x='Ano', y=cols, kind='line', figsize=(10,6))

# Definir título e legendas dos eixos
plt.title('Estimativa da Despesas da India em P&D, saúde e educação (1995-2022)', fontsize=14)
plt.xlabel('Ano', fontsize=12)
plt.ylabel('Despesa (% do PIB)', fontsize=12)

# Colocar legenda fora do gráfico
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# Exibir gráfico
plt.show()

# %%
# Criar uma nova coluna com a década correspondente a cada ano
ind['Decada'] = ((ind['Ano'] // 10) * 10).astype(str) + 's'

# Agrupar os dados por década e calcular a média das outras colunas
ind_por_decada = ind.groupby('Decada').mean()

# Exibir a tabela resultante
ind_por_decada.head(10)

ind_por_decada.to_csv('ind_decada.csv', index=False)
# Out:
# <ipython-input-75-45b9c639715e>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
